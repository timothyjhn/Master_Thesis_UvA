# %% [markdown]
# #Bosdaalen Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
data = pd.read_csv("C:/Users/timot/OneDrive/바탕 화면/Cargoledgerbosdallen.csv")
#display the top 5 rows
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\parsers.py:2061: RuntimeWarning: divide by zero encountered in equal
#   data = self._reader.read(nrows)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# ...

# %%
def tran_countrycode(x):
    if x == "NL":
        return 1
    if x =="DE":
        return 0

# %%
data["trans_countrycode"] = data["countrycode"].apply(tran_countrycode)
data
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in long_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# ...

# %%
data["datetime"]=pd.to_datetime(data.datetime)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:43: RuntimeWarning: divide by zero encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)

# %%
data["datetime1"] = data["datetime"].astype("datetime64[ns]")

# %%
data
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in long_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\concat.py:194: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# ...

# %%
print(data.isnull().sum())
# Out:
# datetime               0
# tripid                 0
# tuid                   0
# description            0
# company                0
#                     ...
# goodsproduct         253
# goodsdescription     389
# goodsreference       320
# trans_countrycode      6
# datetime1              0
# Length: 97, dtype: int64
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2378: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())

# %%
data[data["product"].isnull()]
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1470: RuntimeWarning: divide by zero encountered in equal
#   if ((indexer == -1) | (indexer >= n)).any():
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1470: RuntimeWarning: divide by zero encountered in greater_equal
# ...

# %%
data.shape
# Out:
# (660, 97)

# %%
data.dropna(how = "all").shape
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:344: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
# ...

# %%
data.dropna(subset = ["goodsproduct"],how="all").shape
#data.columns
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\frame.py:5160: RuntimeWarning: divide by zero encountered in equal
#   check = indices == -1
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ...

# %%
print(data['datetime'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(data['datetime'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:326: RuntimeWarning: divide by zero encountered in not_equal
#   mask[1:] = aux[1:] != aux[:-1]
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1607: RuntimeWarning: divide by zero encountered in greater_equal
#   or not np.all(percentiles >= 0)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1608: RuntimeWarning: divide by zero encountered in less_equal
#   or not np.all(percentiles <= 1)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1612: RuntimeWarning: divide by zero encountered in multiply
#   percentiles = 100 * percentiles
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2287: RuntimeWarning: divide by zero encountered in isfinite
# ...

# %%
#distribution of goodsweight
print(data['goodsweight'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(data['goodsweight'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1607: RuntimeWarning: divide by zero encountered in greater_equal
#   or not np.all(percentiles >= 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1608: RuntimeWarning: divide by zero encountered in less_equal
#   or not np.all(percentiles <= 1)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1612: RuntimeWarning: divide by zero encountered in multiply
#   percentiles = 100 * percentiles
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2287: RuntimeWarning: divide by zero encountered in isfinite
#   xfin = isfinite(x)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2288: RuntimeWarning: divide by zero encountered in isfinite
#   yfin = isfinite(y)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2276: RuntimeWarning: divide by zero encountered in subtract
# ...

# %%
print(data['weight'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(data['weight'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1607: RuntimeWarning: divide by zero encountered in greater_equal
#   or not np.all(percentiles >= 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1608: RuntimeWarning: divide by zero encountered in less_equal
#   or not np.all(percentiles <= 1)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\io\formats\format.py:1612: RuntimeWarning: divide by zero encountered in multiply
#   percentiles = 100 * percentiles
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2287: RuntimeWarning: divide by zero encountered in isfinite
#   xfin = isfinite(x)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2288: RuntimeWarning: divide by zero encountered in isfinite
#   yfin = isfinite(y)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2276: RuntimeWarning: divide by zero encountered in subtract
# ...

# %%
data.weight.value_counts().nlargest(40).plot(kind= "bar", figsize=(10,5))
plt.title("Weight of Goods by Kg")
plt.ylabel("Number of Goods")
plt.xlabel("weight")
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:373: RuntimeWarning: divide by zero encountered in invert
#   non_nans = items[~mask]
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:374: RuntimeWarning: divide by zero encountered in invert
#   non_nan_idx = idx[~mask]
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\algorithms.py:1234: RuntimeWarning: divide by zero encountered in negative
#   arr = -arr
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\algorithms.py:1237: RuntimeWarning: divide by zero encountered in subtract
#   arr -= 1
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\algorithms.py:1250: RuntimeWarning: divide by zero encountered in less_equal
#   (ns,) = np.nonzero(arr <= kth_val)
# ...

# %%
#heatmap
plt.figure(figsize=(20,20))
c=data.corr()
sns.heatmap(c,cmap="BrBG", annot=True)
c
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\frame.py:8378: RuntimeWarning: divide by zero encountered in isfinite
#   correl = libalgos.nancorr(mat, minp=min_periods)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:265: RuntimeWarning: divide by zero encountered in bitwise_or
#   result = op(x, y)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:319: RuntimeWarning: divide by zero encountered in reduce
#   res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:320: RuntimeWarning: divide by zero encountered in isnan
#   if np.isnan(res).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:434: RuntimeWarning: divide by zero encountered in reduce
#   res = np.fmax.reduce(a, axis=axis, out=out, **kwargs)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:435: RuntimeWarning: divide by zero encountered in isnan
# ...

# %%
#scatterplot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(data["datetime"], data["weight"])
ax.set_xlabel("datetime")
ax.set_ylabel("weight")
plt.show()
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in less
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\gridspec.py:203: RuntimeWarning: divide by zero encountered in subtract
#   fig_tops, fig_bottoms = (top - cell_hs).reshape((-1, 2)).T
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\gridspec.py:204: RuntimeWarning: divide by zero encountered in add
#   fig_lefts, fig_rights = (left + cell_ws).reshape((-1, 2)).T
# ...

# %%
list(set(data.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('float64'), dtype('int64')]

# %%
data_num = data.select_dtypes(include = ["float64", "int64"])
data_num.head()
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in bitwise_and
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1470: RuntimeWarning: divide by zero encountered in equal
# ...

# %%
data_num.hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8);
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in bitwise_and
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:265: RuntimeWarning: divide by zero encountered in bitwise_and
#   result = op(x, y)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in bitwise_or
# ...

# %%
data_num_corr = data_num.corr()["latitude"][:-1]
golden_features_list = data_num_corr[abs(data_num_corr) > 0.5].sort_values(ascending=False)
print("There are {} strongly correlated values with latitude:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There are 2 strongly correlated values with latitude:
# latitude     1.000000
# longitude   -0.568908
# Name: latitude, dtype: float64
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\frame.py:8378: RuntimeWarning: divide by zero encountered in isfinite
#   correl = libalgos.nancorr(mat, minp=min_periods)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in absolute
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:373: RuntimeWarning: divide by zero encountered in invert
#   non_nans = items[~mask]
# ...

# %%
for i in range(0, len(data_num.columns), 5):
    sns.pairplot(data=data_num, 
                x_vars=data_num.columns[i:i+5],
                y_vars=["latitude"])
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# ...

# %%
from platform import python_version
print (python_version())
# Out:
# 3.8.8

# %%
data.tail(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# ...

# %%
#checking data types
data.dtypes
# Out:
# datetime              object
# tripid                 int64
# tuid                  object
# description           object
# company                int64
#                       ...
# goodspalletplaces    float64
# goodscolli           float64
# goodsproduct          object
# goodsdescription      object
# goodsreference        object
# Length: 95, dtype: object

# %%
#drop irrrelevant columns
data = data.drop(["drivercode", "driverpassword", "driverfirstname", "driverlastname", "driveremail", "driverphone", "codriver", "codriverfirstname", "codriverlastname", "codriverphone", "codriveremail"], axis=1)
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5588: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# ...

# %%
data = data.rename(columns={"description2": "companyname"})
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# ...

# %%
data = data.rename(columns={"deliverydatetime": "delivery_datetime"})
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2378: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# ...

# %%
#drop duplicate rows
data.shape
# Out:
# (660, 84)

# %%
duplicate_rows_data = data[data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\algorithms.py:731: RuntimeWarning: divide by zero encountered in equal
#   code_is_na = codes == na_sentinel
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:137: RuntimeWarning: divide by zero encountered in equal
#   return (lab + 1, size + 1) if (lab == -1).any() else (lab, size)
# number of duplicate rows:  (0, 84)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:137: RuntimeWarning: divide by zero encountered in add
#   return (lab + 1, size + 1) if (lab == -1).any() else (lab, size)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:154: RuntimeWarning: divide by zero encountered in multiply
#   out = stride * labels[0].astype("i8", subok=False, copy=False)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\sorting.py:160: RuntimeWarning: divide by zero encountered in longlong_scalars
#   stride //= shape[i]
# ...

# %%
data.count()
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2378: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# datetime             660
# tripid               660
# tuid                 660
# description          660
# company              660
#                     ...
# goodspalletplaces    448
# goodscolli           304
# goodsproduct         407
# goodsdescription     271
# goodsreference       340
# Length: 84, dtype: int64

# %%
data = data.drop_duplicates()
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\generic.py:1401: RuntimeWarning: divide by zero encountered in invert
#   arr = operator.inv(values)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# ...

# %%
data.count()
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# datetime             660
# tripid               660
# tuid                 660
# description          660
# company              660
#                     ...
# goodspalletplaces    448
# goodscolli           304
# goodsproduct         407
# goodsdescription     271
# goodsreference       340
# Length: 84, dtype: int64

# %%
#dropping missing our null values
print(data.isnull().sum())
# Out:
# datetime               0
# tripid                 0
# tuid                   0
# description            0
# company                0
#                     ...
# goodspalletplaces    212
# goodscolli           356
# goodsproduct         253
# goodsdescription     389
# goodsreference       320
# Length: 84, dtype: int64

# %%
data = data.dropna()
data.count()
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1470: RuntimeWarning: divide by zero encountered in equal
# ...

# %%
print(data.isnull().sum())
# Out:
# datetime             0
# tripid               0
# tuid                 0
# description          0
# company              0
#                     ..
# goodspalletplaces    0
# goodscolli           0
# goodsproduct         0
# goodsdescription     0
# goodsreference       0
# Length: 84, dtype: int64

# %%
data.head(5)
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:246: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:54: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\numeric.py:2378: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# ...

# %%
sns.boxplot(x=data["weight"])
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
# ...

# %%
sns.boxplot(x=data["colli"])
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
# ...

# %%
sns.boxplot(x=data["goodsweight"])
# Out:
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:235: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in equal
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:580: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask |= (ar1 == a)
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\timot\anaconda3\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\timot\anaconda3\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
# ...

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# tripid                247.250000
# company                 0.000000
# plangroup               0.000000
# tripnumber            247.250000
# stopid               1005.000000
# sortnumber              1.000000
# stopaction             10.000000
# stopduration            0.000000
# latitude                0.000000
# longitude               0.326325
# activityid           3435.500000
# action                 10.000000
# shipmentid           2809.000000
# customernr             34.500000
# customerid             34.500000
# quantity                0.500000
# weight                757.740000
# loadingmeter            0.100000
# palletplaces            0.290000
# colli                 189.750000
# goodslineid          1905.250000
# goodssortnumber         0.000000
# goodsquantity           0.500000
# goodsweight           923.940000
# goodsloadingmeter       0.100000
# goodspalletplaces       0.790000
# goodscolli            215.000000
# dtype: float64
# ...

# %%
data = data[~((data< (Q1 - 1.5 * IQR)) | (data > ( Q3 + 1.5 * IQR))).any(axis=1)]
data.shape
# Out:
# <ipython-input-30-61a55e1f4de5>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data = data[~((data< (Q1 - 1.5 * IQR)) | (data > ( Q3 + 1.5 * IQR))).any(axis=1)]
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2750: RuntimeWarning: divide by zero encountered in equal
#   indexer = (indexer == -1).nonzero()[0]
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1423: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:258: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\timot\anaconda3\lib\site-packages\pandas\core\indexers.py:263: RuntimeWarning: divide by zero encountered in greater_equal
# ...
